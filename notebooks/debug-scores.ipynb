# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/Users/chahanvidal-gorene/Documents/encours/expe_compet.csv')

# %%
data.sort_values('score', ascending=False)
# Out:
#                                modele  size  iou  conf  precision  recall  \
# 50  ext_vers_model_2023_04_13_full-v2  2176  0.1   0.1      0.872   0.696
# 37  ext_vers_model_2023_04_13_full-v2  2048  0.1   0.1      0.883   0.681
# 51  ext_vers_model_2023_04_13_full-v2  2240  0.1   0.1      0.848   0.720
# 30     ext_vers_model_2023_04_13_full  2048  0.1   0.1      0.841   0.717
# 33     ext_vers_model_2023_04_13_full  2176  0.1   0.1      0.851   0.708
# ..                                ...   ...  ...   ...        ...     ...
# 68              model_2023_04_17_giga  3072  0.2   NaN      0.836   0.664
# 69              model_2023_04_17_giga  3072  0.2   0.5      0.836   0.664
# 70             model_2023_04_17_hypra  1536  NaN   NaN      0.797   0.650
# 72             model_2023_04_17_hypra  2048  NaN   NaN      0.758   0.674
# 73             model_2023_04_17_hypra  2048  0.1   0.1      0.858   0.710
#
#       mAP  mAP50-95      score  soumission
# ...

# %%
data_score = data[data['score'].notna()]

# %%
data_score.sort_values('score', ascending=False)
# Out:
#                                modele  size  iou  conf  precision  recall  \
# 50  ext_vers_model_2023_04_13_full-v2  2176  0.1  0.10      0.872   0.696
# 37  ext_vers_model_2023_04_13_full-v2  2048  0.1  0.10      0.883   0.681
# 51  ext_vers_model_2023_04_13_full-v2  2240  0.1  0.10      0.848   0.720
# 30     ext_vers_model_2023_04_13_full  2048  0.1  0.10      0.841   0.717
# 33     ext_vers_model_2023_04_13_full  2176  0.1  0.10      0.851   0.708
# 36  ext_vers_model_2023_04_13_full-v2  2048  0.1  0.10      0.807   0.725
# 29     ext_vers_model_2023_04_13_full  2048  0.1  0.10      0.831   0.702
# 34  ext_vers_model_2023_04_13_full-v2  1536  0.1  0.10      0.805   0.713
# 16              model_2023_04_13_full  2048  0.1  0.10      0.838   0.703
# 18              model_2023_04_13_full  2048  0.2  0.10      0.830   0.703
# 7               model_2023_04_04_full  2048  0.2  0.10      0.834   0.707
# 1               model_2023_04_04_full  2048  NaN   NaN      0.812   0.666
# ...

# %%
data_highest = data[(data['precision'] > 0.8) & (data['recall'] > 0.68) & (data['mAP'] > 0.8)]

# %%
data_highest
# Out:
#                                modele  size  iou  conf  precision  recall  \
# 16              model_2023_04_13_full  2048  0.1  0.10      0.838   0.703
# 17              model_2023_04_13_full  2048  0.1  0.25      0.842   0.699
# 18              model_2023_04_13_full  2048  0.2  0.10      0.830   0.703
# 26              model_2023_04_13_full  2560  0.1  0.10      0.861   0.690
# 27              model_2023_04_13_full  2560  0.1  0.35      0.862   0.690
# 29     ext_vers_model_2023_04_13_full  2048  0.1  0.10      0.831   0.702
# 30     ext_vers_model_2023_04_13_full  2048  0.1  0.10      0.841   0.717
# 31     ext_vers_model_2023_04_13_full  2048  0.1  0.25      0.835   0.698
# 33  ext_vers_model_2023_04_13_full-v2  1536  0.1  0.10      0.805   0.713
# 35  ext_vers_model_2023_04_13_full-v2  2048  0.1  0.10      0.807   0.725
# 36  ext_vers_model_2023_04_13_full-v2  2048  0.1  0.10      0.883   0.681
# 50             model_2023_04_17_hypra  1536  0.1  0.10      0.855   0.713
# ...

# %%
data_highest.sort_values('precision', ascending=False)
# Out:
#                                modele  size  iou  conf  precision  recall  \
# 36  ext_vers_model_2023_04_13_full-v2  2048  0.1  0.10      0.883   0.681
# 27              model_2023_04_13_full  2560  0.1  0.35      0.862   0.690
# 26              model_2023_04_13_full  2560  0.1  0.10      0.861   0.690
# 52             model_2023_04_17_hypra  2048  0.1  0.10      0.858   0.710
# 50             model_2023_04_17_hypra  1536  0.1  0.10      0.855   0.713
# 17              model_2023_04_13_full  2048  0.1  0.25      0.842   0.699
# 30     ext_vers_model_2023_04_13_full  2048  0.1  0.10      0.841   0.717
# 16              model_2023_04_13_full  2048  0.1  0.10      0.838   0.703
# 31     ext_vers_model_2023_04_13_full  2048  0.1  0.25      0.835   0.698
# 29     ext_vers_model_2023_04_13_full  2048  0.1  0.10      0.831   0.702
# 18              model_2023_04_13_full  2048  0.2  0.10      0.830   0.703
# 35  ext_vers_model_2023_04_13_full-v2  2048  0.1  0.10      0.807   0.725
# ...

# %%
data_highest.sort_values('recall', ascending=False)
# Out:
#                                modele  size  iou  conf  precision  recall  \
# 35  ext_vers_model_2023_04_13_full-v2  2048  0.1  0.10      0.807   0.725
# 30     ext_vers_model_2023_04_13_full  2048  0.1  0.10      0.841   0.717
# 33  ext_vers_model_2023_04_13_full-v2  1536  0.1  0.10      0.805   0.713
# 50             model_2023_04_17_hypra  1536  0.1  0.10      0.855   0.713
# 52             model_2023_04_17_hypra  2048  0.1  0.10      0.858   0.710
# 16              model_2023_04_13_full  2048  0.1  0.10      0.838   0.703
# 18              model_2023_04_13_full  2048  0.2  0.10      0.830   0.703
# 29     ext_vers_model_2023_04_13_full  2048  0.1  0.10      0.831   0.702
# 17              model_2023_04_13_full  2048  0.1  0.25      0.842   0.699
# 31     ext_vers_model_2023_04_13_full  2048  0.1  0.25      0.835   0.698
# 26              model_2023_04_13_full  2560  0.1  0.10      0.861   0.690
# 27              model_2023_04_13_full  2560  0.1  0.35      0.862   0.690
# ...

# %%
data_highest.sort_values('mAP', ascending=False)
# Out:
#                                modele  size  iou  conf  precision  recall  \
# 36  ext_vers_model_2023_04_13_full-v2  2048  0.1  0.10      0.883   0.681
# 50             model_2023_04_17_hypra  1536  0.1  0.10      0.855   0.713
# 16              model_2023_04_13_full  2048  0.1  0.10      0.838   0.703
# 30     ext_vers_model_2023_04_13_full  2048  0.1  0.10      0.841   0.717
# 29     ext_vers_model_2023_04_13_full  2048  0.1  0.10      0.831   0.702
# 52             model_2023_04_17_hypra  2048  0.1  0.10      0.858   0.710
# 17              model_2023_04_13_full  2048  0.1  0.25      0.842   0.699
# 18              model_2023_04_13_full  2048  0.2  0.10      0.830   0.703
# 33  ext_vers_model_2023_04_13_full-v2  1536  0.1  0.10      0.805   0.713
# 26              model_2023_04_13_full  2560  0.1  0.10      0.861   0.690
# 27              model_2023_04_13_full  2560  0.1  0.35      0.862   0.690
# 35  ext_vers_model_2023_04_13_full-v2  2048  0.1  0.10      0.807   0.725
# ...

# %%
data_highest.sort_values('mAP50-95', ascending=False)
# Out:
#                                modele  size  iou  conf  precision  recall  \
# 17              model_2023_04_13_full  2048  0.1  0.25      0.842   0.699
# 27              model_2023_04_13_full  2560  0.1  0.35      0.862   0.690
# 16              model_2023_04_13_full  2048  0.1  0.10      0.838   0.703
# 31     ext_vers_model_2023_04_13_full  2048  0.1  0.25      0.835   0.698
# 29     ext_vers_model_2023_04_13_full  2048  0.1  0.10      0.831   0.702
# 36  ext_vers_model_2023_04_13_full-v2  2048  0.1  0.10      0.883   0.681
# 26              model_2023_04_13_full  2560  0.1  0.10      0.861   0.690
# 18              model_2023_04_13_full  2048  0.2  0.10      0.830   0.703
# 33  ext_vers_model_2023_04_13_full-v2  1536  0.1  0.10      0.805   0.713
# 50             model_2023_04_17_hypra  1536  0.1  0.10      0.855   0.713
# 35  ext_vers_model_2023_04_13_full-v2  2048  0.1  0.10      0.807   0.725
# 52             model_2023_04_17_hypra  2048  0.1  0.10      0.858   0.710
# ...

# %%
data.sort_values('precision', ascending=False)
# Out:
#                                modele  size  iou  conf  precision  recall  \
# 6               model_2023_04_04_full  2048  0.2  0.90      0.953   0.359
# 25              model_2023_04_13_full  2048  0.8  0.75      0.948   0.519
# 24              model_2023_04_13_full  2048  0.8  0.65      0.917   0.626
# 36  ext_vers_model_2023_04_13_full-v2  2048  0.1  0.10      0.883   0.681
# 37              model_2023_04_16_giga  2048  0.2   NaN      0.873   0.605
# 23              model_2023_04_13_full  2048  0.8  0.55      0.872   0.667
# 39              model_2023_04_16_giga  3072  0.2   NaN      0.870   0.652
# 2               model_2023_04_04_full  2048  NaN  0.20      0.867   0.675
# 3               model_2023_04_04_full  2048  NaN   NaN      0.867   0.675
# 4               model_2023_04_04_full  2048  NaN  0.10      0.867   0.675
# 5               model_2023_04_04_full  2048  0.2  0.50      0.865   0.676
# 32     ext_vers_model_2023_04_13_full  2048  0.1  0.50      0.864   0.675
# ...

# %%
data['indice'] = (data['precision'] + data['recall'] + data['mAP'] + data['mAP50-95'])/4

# %%
data.sort_values('indice', ascending=False)
# Out:
#                                modele  size  iou  conf  precision  recall  \
# 43  ext_vers_model_2023_04_13_full-v2  2048  0.1   0.5      0.883   0.691
# 50  ext_vers_model_2023_04_13_full-v2  2240  0.1   0.1      0.848   0.720
# 49  ext_vers_model_2023_04_13_full-v2  2176  0.1   0.1      0.872   0.696
# 36  ext_vers_model_2023_04_13_full-v2  2048  0.1   0.1      0.883   0.681
# 40  ext_vers_model_2023_04_13_full-v2  2048  0.1   0.2      0.883   0.681
# ..                                ...   ...  ...   ...        ...     ...
# 11              model_2023_04_13_full  2048  NaN   NaN      0.763   0.627
# 13              model_2023_04_13_full  2176  NaN   NaN      0.751   0.629
# 12              model_2023_04_13_full  2112  NaN   NaN      0.752   0.628
# 46  ext_vers_model_2023_04_13_full-v2  2048  0.1   0.8      0.963   0.388
# 6               model_2023_04_04_full  2048  0.2   0.9      0.953   0.359
#
#       mAP  mAP50-95      score  soumission   indice
# ...

# %%
data
# Out:
#                     modele  size  iou  conf  precision  recall    mAP  \
# 0    model_2023_04_04_full  1536  NaN   NaN      0.812   0.648  0.757
# 1    model_2023_04_04_full  2048  NaN   NaN      0.812   0.666  0.767
# 2    model_2023_04_04_full  2048  NaN   0.2      0.867   0.675  0.787
# 3    model_2023_04_04_full  2048  NaN   NaN      0.867   0.675  0.787
# 4    model_2023_04_04_full  2048  NaN   0.1      0.867   0.675  0.787
# ..                     ...   ...  ...   ...        ...     ...    ...
# 69   model_2023_04_17_giga  3072  0.2   0.5      0.836   0.664  0.779
# 70  model_2023_04_17_hypra  1536  NaN   NaN      0.797   0.650  0.753
# 71  model_2023_04_17_hypra  1536  0.1   0.1      0.855   0.713  0.809
# 72  model_2023_04_17_hypra  2048  NaN   NaN      0.758   0.674  0.752
# 73  model_2023_04_17_hypra  2048  0.1   0.1      0.858   0.710  0.806
#
#     mAP50-95      score  soumission
# 0      0.454  35.334926         2.0
# 1      0.467  36.322530         4.0
# ...
